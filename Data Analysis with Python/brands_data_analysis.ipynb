# %% [markdown]
# # Brands Table Data Exploration

# %%
import pandas as pd
from datetime import datetime
import json

# %%
# Function to convert Id and timestamp structures to Python objects
def convert_objects(row):
    for key, value in row.items():
        if isinstance(value, dict) and "$oid" in value:
            row[key] = value["$oid"]
        # Convert Date in Unix timestamp format (milliseconds since the epoch)
        elif isinstance(value, dict) and "$date" in value:
            timestamp = value["$date"] / 1000  # Convert milliseconds to seconds
            row[key] = datetime.fromtimestamp(timestamp)
    return row

# %%
# Read and convert the JSON file
brands_df = pd.read_json('brands.json', lines=True)
brands_df = brands_df.apply(convert_objects, axis=1)
brands_df.head()
# Out:
#                         _id       barcode        category      categoryCode  \
# 0  601ac115be37ce2ead437551  511111019862          Baking            BAKING
# 1  601c5460be37ce2ead43755f  511111519928       Beverages         BEVERAGES
# 2  601ac142be37ce2ead43755d  511111819905          Baking            BAKING
# 3  601ac142be37ce2ead43755a  511111519874          Baking            BAKING
# 4  601ac142be37ce2ead43755e  511111319917  Candy & Sweets  CANDY_AND_SWEETS
#
#                                                  cpg  \
# 0  {'$id': {'$oid': '601ac114be37ce2ead437550'}, ...
# 1  {'$id': {'$oid': '5332f5fbe4b03c9a25efd0ba'}, ...
# 2  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 3  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 4  {'$id': {'$oid': '5332fa12e4b03c9a25efd1e7'}, ...
#
#                         name  topBrand                      brandCode
# 0  test brand @1612366101024       0.0                            NaN
# 1                  Starbucks       0.0                      STARBUCKS
# 2  test brand @1612366146176       0.0  TEST BRANDCODE @1612366146176
# 3  test brand @1612366146051       0.0  TEST BRANDCODE @1612366146051
# 4  test brand @1612366146827       0.0  TEST BRANDCODE @1612366146827

# %%
#fix nested structure in cpg column and concat to the brands table
cpg=pd.json_normalize(brands_df['cpg'])
cpg.columns=['cpg_ref', 'cpg_id']
brands_df=pd.concat([brands_df,cpg], axis=1)
brands_df=brands_df.drop(columns=['cpg'])
brands_df.head()
# Out:
#                         _id       barcode        category      categoryCode  \
# 0  601ac115be37ce2ead437551  511111019862          Baking            BAKING
# 1  601c5460be37ce2ead43755f  511111519928       Beverages         BEVERAGES
# 2  601ac142be37ce2ead43755d  511111819905          Baking            BAKING
# 3  601ac142be37ce2ead43755a  511111519874          Baking            BAKING
# 4  601ac142be37ce2ead43755e  511111319917  Candy & Sweets  CANDY_AND_SWEETS
#
#                         name  topBrand                      brandCode cpg_ref  \
# 0  test brand @1612366101024       0.0                            NaN    Cogs
# 1                  Starbucks       0.0                      STARBUCKS    Cogs
# 2  test brand @1612366146176       0.0  TEST BRANDCODE @1612366146176    Cogs
# 3  test brand @1612366146051       0.0  TEST BRANDCODE @1612366146051    Cogs
# 4  test brand @1612366146827       0.0  TEST BRANDCODE @1612366146827    Cogs
#
#                      cpg_id
# 0  601ac114be37ce2ead437550
# 1  5332f5fbe4b03c9a25efd0ba
# 2  601ac142be37ce2ead437559
# 3  601ac142be37ce2ead437559
# 4  5332fa12e4b03c9a25efd1e7

# %%
#check brands table information
brands_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1167 entries, 0 to 1166
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   _id           1167 non-null   object
#  1   barcode       1167 non-null   int64
#  2   category      1012 non-null   object
#  3   categoryCode  517 non-null    object
#  4   name          1167 non-null   object
#  5   topBrand      555 non-null    float64
#  6   brandCode     933 non-null    object
#  7   cpg_ref       1167 non-null   object
#  8   cpg_id        1167 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 82.2+ KB

# %%
#checking null counts
brands_df.isnull().sum()
# Out:
# _id               0
# barcode           0
# category        155
# categoryCode    650
# name              0
# topBrand        612
# brandCode       234
# cpg_ref           0
# cpg_id            0
# dtype: int64

# %%
#checking null percentages
brands_df.isnull().mean()
# Out:
# _id             0.000000
# barcode         0.000000
# category        0.132819
# categoryCode    0.556984
# name            0.000000
# topBrand        0.524422
# brandCode       0.200514
# cpg_ref         0.000000
# cpg_id          0.000000
# dtype: float64

# %%
#cheacking for duplicated records
brands_df[brands_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [_id, barcode, category, categoryCode, name, topBrand, brandCode, cpg_ref, cpg_id]
# Index: []

# %%
#checking unique counts for fields that should have uniwue values
print(brands_df["_id"].nunique())
print(brands_df["barcode"].nunique())
print(brands_df["name"].nunique())
# Out:
# 1167
# 1160
# 1156

# %%
#checking for duplicated barcodes
duplicated_barcodes=brands_df[brands_df['barcode'].duplicated()]
brands_df[brands_df['barcode'].isin(duplicated_barcodes['barcode'])].sort_values('barcode')
# Out:
#                            _id       barcode             category  \
# 467   5c409ab4cd244a3539b84162  511111004790               Baking
# 1071  5cdacd63166eb33eb7ce0fa8  511111004790  Condiments & Sauces
# 152   5c45f91b87ff3552f950f027  511111204923              Grocery
# 536   5d6027f46d5f3b23d1bc7906  511111204923               Snacks
# 20    5c4699f387ff3577e203ea29  511111305125                 Baby
# 651   5d642d65a3a018514994f42d  511111305125            Magazines
# 129   5a7e0604e4b0aedb3b84afd3  511111504139            Beverages
# 299   5a8c33f3e4b07f0a2dac8943  511111504139              Grocery
# 9     5c408e8bcd244a1fdb47aee7  511111504788               Baking
# 412   5ccb2ece166eb31bbbadccbe  511111504788  Condiments & Sauces
# 194   5d6415d5a3a018514994f429  511111605058            Magazines
# 1012  5c4637ba87ff35681e840d57  511111605058                Dairy
# 1002  5a8c344ae4b0ccf165fac9e5  511111704140  Condiments & Sauces
# 1015  5a7e0665e4b0aedb3b84afd4  511111704140                  NaN
#
#      categoryCode                  name  topBrand      brandCode cpg_ref  \
# 467           NaN                 alexa       1.0          ALEXA    Cogs
# 1071          NaN       Bitten Dressing       NaN         BITTEN    Cogs
# 152           NaN                Brand1       1.0     0987654321    Cogs
# 536           NaN             CHESTER'S       NaN       CHESTERS    Cogs
# 20            NaN      Chris Image Test       NaN     CHRISIMAGE    Cogs
# 651           NaN  Rachael Ray Everyday       NaN   511111305125    Cogs
# 129           NaN       Chris Brand XYZ       NaN       CHRISXYZ    Cogs
# 299           NaN                  Pace       0.0           PACE    Cogs
# 9             NaN                  test       NaN           TEST    Cogs
# 412           NaN     The Pioneer Woman       NaN  PIONEER WOMAN    Cogs
# 194           NaN       Health Magazine       NaN   511111605058    Cogs
# 1012          NaN                Brand2       1.0    09090909090    Cogs
# 1002          NaN                 Prego       0.0          PREGO    Cogs
# 1015          NaN       Diet Chris Cola       NaN     DIETCHRIS2    Cogs
#
#                         cpg_id
# 467   55b62995e4b0d8e685c14213
# 1071  559c2234e4b06aca36af13c6
# 152   5c45f8b087ff3552f950f026
# 536   5332f5fbe4b03c9a25efd0ba
# 20    55b62995e4b0d8e685c14213
# 651   5d5d4fd16d5f3b23d1bc7905
# 129   55b62995e4b0d8e685c14213
# 299   5a734034e4b0d58f376be874
# 9     59ba6f1ce4b092b29c167346
# 412   559c2234e4b06aca36af13c6
# 194   5d5d4fd16d5f3b23d1bc7905
# 1012  5c45f8b087ff3552f950f026
# 1002  5a734034e4b0d58f376be874
# 1015  55b62995e4b0d8e685c14213

# %%
#checking duplicated brand names
duplicated_names=brands_df[brands_df['name'].duplicated()]
brands_df[brands_df['name'].isin(duplicated_names['name'])].sort_values('name')
# Out:
#                            _id       barcode              category  \
# 848   585a961fe4b03e62d1ce0e76  511111701781                Snacks
# 574   5d9d08d1a60b87376833e348  511111605546                Snacks
# 140   5a4d23dae4b0bcb2c74ea77e  511111000518             Beverages
# 740   5d601d74a3a018514994f422  511111004912                Snacks
# 1007  5d658ffa6d5f3b23d1bc7914  511111205227                   NaN
# 1006  5d66d597a3a018093ab34726  511111805298             Magazines
# 1163  5dc1fca91dda2c0ad7da64ae  511111706328    Breakfast & Cereal
# 1081  5dc2d9d4a60b873d6b0666d2  511111206330    Breakfast & Cereal
# 194   5d6415d5a3a018514994f429  511111605058             Magazines
# 596   5f298852be37ce7958c5952d  511111915287             Magazines
# 1074  5c7d9cb395144c337a3cbfbb  511111707202                  Baby
# 628   5bd2011f90fa074576779a17  511111704652                  Baby
# 846   5e710dd5ee7f2d0b35b2a193  511111314097  Dairy & Refrigerated
# 176   592486bee410d61fcea3d12d  511111700814                 Dairy
# 339   5e5ff265ee7f2d0b35b2a18f  511111914051     Health & Wellness
# 64    5da609991dda2c3e1416ae90  511111805854     Health & Wellness
# 978   5db3288aee7f2d6de4248977  511111312949                  Baby
# 126   5bd201a990fa074576779a19  511111104698                  Baby
# 282   5332f608e4b03c9a25efd0c1  511111903901                   NaN
# 1116  5d66e07da3a018093ab3472d  511111205500             Beverages
# 477   5bcdfc5a965c7d66d92731e9  511111304616             Beverages
# 1025  5bcdfc5990fa074576779a15  511111804604             Beverages
#
#                 categoryCode                              name  topBrand  \
# 848                      NaN                         Baken-Ets       1.0
# 574                      NaN                         Baken-Ets       NaN
# 140                      NaN                      Caleb's Kola       0.0
# 740                      NaN                      Caleb's Kola       NaN
# 1007                     NaN          Diabetic Living Magazine       NaN
# 1006                     NaN          Diabetic Living Magazine       NaN
# 1163                     NaN               Dippin Dots® Cereal       NaN
# 1081                     NaN               Dippin Dots® Cereal       NaN
# 194                      NaN                   Health Magazine       NaN
# 596                MAGAZINES                   Health Magazine       NaN
# 1074                    BABY                           Huggies       1.0
# 628                      NaN                           Huggies       0.0
# 846   DAIRY_AND_REFRIGERATED  I CAN'T BELIEVE IT'S NOT BUTTER!       NaN
# 176                      NaN  I CAN'T BELIEVE IT'S NOT BUTTER!       NaN
# 339                      NaN                 ONE A DAY® WOMENS       NaN
# 64                       NaN                 ONE A DAY® WOMENS       0.0
# 978                      NaN                          Pull-Ups       1.0
# 126                      NaN                          Pull-Ups       0.0
# 282                      NaN                       Sierra Mist       NaN
# 1116                     NaN                       Sierra Mist       NaN
# 477                      NaN                        V8 Hydrate       NaN
# 1025                     NaN                        V8 Hydrate       0.0
#
#                              brandCode cpg_ref                    cpg_id
# 848                          BAKEN-ETS    Cogs  5332f5fbe4b03c9a25efd0ba
# 574                          BAKEN ETS    Cogs  5332f5fbe4b03c9a25efd0ba
# 140                       CALEB'S KOLA    Cogs  5332f5fbe4b03c9a25efd0ba
# 740                        CALEBS KOLA    Cogs  53e10d6368abd3c7065097cc
# 1007                               NaN    Cogs  53e10d6368abd3c7065097cc
# 1006                      511111805298    Cogs  5d5d4fd16d5f3b23d1bc7905
# 1163                DIPPIN DOTS CEREAL    Cogs  53e10d6368abd3c7065097cc
# 1081                       DIPPIN DOTS    Cogs  5332f5f3e4b03c9a25efd0ae
# 194                       511111605058    Cogs  5d5d4fd16d5f3b23d1bc7905
# 596                             HEALTH    Cogs  5d66b9dcee7f2d201c7281cd
# 1074                           HUGGIES    Cogs  5459429be4b0bfcb1e864082
# 628                            HUGGIES    Cogs  550b2565e4b001d5e9e4146f
# 846    I CAN'T BELIEVE IT'S NOT BUTTER    Cogs  5e5ea9cc9c50da1291a6d074
# 176   I CAN'T BELIEVE IT'S NOT BUTTER!    Cogs  53e10d6368abd3c7065097cc
# 339                  ONE A DAY® WOMENS    Cogs  53e10d6368abd3c7065097cc
# 64                        511111805854    Cogs  53e10d6368abd3c7065097cc
# 978                            PULLUPS    Cogs  550b2565e4b001d5e9e4146f
# 126                           PULL UPS    Cogs  550b2565e4b001d5e9e4146f
# 282                                NaN    Cpgs  53e10d6368abd3c7065097cc
# 1116                       SIERRA MIST    Cogs  5332f5fbe4b03c9a25efd0ba
# 477                                NaN    Cogs  53e10d6368abd3c7065097cc
# 1025                        V8 HYDRATE    Cogs  5a734034e4b0d58f376be874

# %%
#checking duplicated brandcodes
duplicated_brandcodes=brands_df[~brands_df['brandCode'].isnull()]
duplicated_brandcodes=duplicated_brandcodes[duplicated_brandcodes['brandCode'].duplicated()]
duplicated_brandcodes.head()
# Out:
#                           _id       barcode           category categoryCode  \
# 153  58861c7d4e8d0d20bc42c4d6  511111601449             Snacks          NaN
# 163  57ebc2ace4b0ac389136a346  511111801962               Deli          NaN
# 188  58b59989e4b0857c2ddb7255  511111400998  Beer Wine Spirits          NaN
# 234  58b5988ce4b0857c2ddb7252  511111301028  Beer Wine Spirits          NaN
# 236  57ebc125e4b0ac389136a33b  511111302063            Grocery          NaN
#
#                                       name  topBrand brandCode cpg_ref  \
# 153  Jell-O Refrigerated Pudding & Gelatin       0.0              Cogs
# 163                                     P3       0.0              Cogs
# 188                          Redd's Wicked       0.0              Cogs
# 234                 Henry's Hard Sparkling       0.0              Cogs
# 236                Kraft Macaroni & Cheese       0.0              Cogs
#
#                        cpg_id
# 153  559c2234e4b06aca36af13c6
# 163  559c2234e4b06aca36af13c6
# 188  5332f709e4b03c9a25efd0f1
# 234  5332f709e4b03c9a25efd0f1
# 236  559c2234e4b06aca36af13c6

# %%
#removing records with empty strings for brandcode and checking records
duplicated_brandcodes=duplicated_brandcodes[duplicated_brandcodes['brandCode']!='']
brands_df[brands_df['brandCode'].isin(duplicated_brandcodes['brandCode'])]
# Out:
#                            _id       barcode category categoryCode       name  \
# 628   5bd2011f90fa074576779a17  511111704652     Baby          NaN    Huggies
# 1036  5db32879ee7f2d6de4248976  511111112938     Baby         BABY  GoodNites
# 1074  5c7d9cb395144c337a3cbfbb  511111707202     Baby         BABY    Huggies
# 1079  5bd200fc965c7d66d92731eb  511111204640     Baby          NaN  Goodnites
#
#       topBrand  brandCode cpg_ref                    cpg_id
# 628        0.0    HUGGIES    Cogs  550b2565e4b001d5e9e4146f
# 1036       1.0  GOODNITES    Cogs  55b62995e4b0d8e685c14213
# 1074       1.0    HUGGIES    Cogs  5459429be4b0bfcb1e864082
# 1079       0.0  GOODNITES    Cogs  550b2565e4b001d5e9e4146f

# %%
#checking records where brandcodes have an empty string
len(brands_df[brands_df['brandCode']==''])
# Out:
# 35

# %%
#checking other columns for empty strings
print(len(brands_df[brands_df['category']=='']))
print(len(brands_df[brands_df['categoryCode']=='']))
print(len(brands_df[brands_df['name']=='']))
print(len(brands_df[brands_df['topBrand']=='']))
print(len(brands_df[brands_df['cpg_ref']=='']))
# Out:
# 0
# 0
# 0
# 0
# 0

# %%
#checking value counts for topBrand
brands_df['topBrand'].value_counts()
# Out:
# topBrand
# 0.0    524
# 1.0     31
# Name: count, dtype: int64

# %%
#checking value counts of category
brands_df['category'].value_counts()
# Out:
# category
# Baking                         369
# Beer Wine Spirits               90
# Snacks                          75
# Candy & Sweets                  71
# Beverages                       63
# Magazines                       44
# Health & Wellness               44
# Breakfast & Cereal              40
# Grocery                         39
# Dairy                           33
# Condiments & Sauces             27
# Frozen                          24
# Personal Care                   20
# Baby                            18
# Canned Goods & Soups            12
# Beauty                           9
# Cleaning & Home Improvement      6
# Deli                             6
# Beauty & Personal Care           6
# Household                        5
# Bread & Bakery                   5
# Dairy & Refrigerated             5
# Outdoor                          1
# Name: count, dtype: int64

# %%
#checking value counts of categoryCode
brands_df['categoryCode'].value_counts()
# Out:
# categoryCode
# BAKING                           359
# CANDY_AND_SWEETS                  71
# BEER_WINE_SPIRITS                 31
# HEALTHY_AND_WELLNESS              14
# GROCERY                           11
# BABY                               7
# CLEANING_AND_HOME_IMPROVEMENT      6
# BREAD_AND_BAKERY                   5
# DAIRY_AND_REFRIGERATED             5
# PERSONAL_CARE                      4
# BEVERAGES                          1
# OUTDOOR                            1
# MAGAZINES                          1
# FROZEN                             1
# Name: count, dtype: int64

# %% [markdown]
# ### Data quality Issues: Brands Table
#
# 1. Null Values
#     There's a large percentage of null values for the following fields
#
#         category        13.3%
#         categoryCode    55.7%
#         topBrand        52.4%
#         brandCode       20.1%
#
#     The large number of missing values can cause issues with analysis and marketing efforts.
#     categoryCode and brandCode are important to connect this table with other tables like receipt_items, which has a brandCode field to pull in brand information.
#     The majority of null values for categoryCode are from records that don't have category as 'Baking' or 'Candy & Sweets'.
#     topBrand is an important field to imporve marketing efforts. The majority of these null records will have an indicator of '0.0'; however, we will miss out on marketing opportunities for the brands that should be indicated as a top brand.
#
#     Reccomendations:
#
#     Null fields for category and topBrand need to be corrected on data entry.
#     Null fields for categoryCode can be substituted using the categoryCode for other records with the same category; however there will still be some categories with null values for the categoryCode. A new categoryCode will need to be made for these records.
#     Null fields in the brandCode can be substituted with a value using the name.
#
#     note: brandCode and categoryCode issues should be corrected during the ETL process accross all tables with the features as these are joinable keys and should be standardized accross the tables
#
#
# 2. Duplicated records
#
#     There are no fully duplicated records in this data; however there are duplicates in the following fields: barcode, name, brandCode.
#
#     barcode: There are 7 barcodes that are duplicated with differrent brand information. This should be discussed with the stakeholder to see if this is a data issue or if the barcode is correct.
#
#     name: There are 11 brand names that are duplicated with varying information in the other columns. Some have different topBrand indicators, brandCodes, category, or categoryCodes.
#
#     brandcode: There are 2 brandCodes that are duplicated. The main difference in the duplicated records is the topBrand indicator.
